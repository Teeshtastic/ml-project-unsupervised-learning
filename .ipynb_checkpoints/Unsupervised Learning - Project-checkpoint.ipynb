# %% [markdown]
# # Supervised Learning - Project

# %% [markdown]
# In this Project, we are going to perform a full unsupervised learning machine learning project on a "Wholesale Data" dataset. The dataset refers to clients of a wholesale distributor. It includes the annual spending in monetary units (m.u.) on diverse product categories
#
# [Kaggle Link](https://www.kaggle.com/datasets/binovi/wholesale-customers-data-set)

# %% [markdown]
# # Part I : EDA - Exploratory Data Analysis & Pre-processing

# %% [markdown]
# The given dataset seems to be a grocery sales dataset containing information about various products sold by a grocery store. To perform an exploratory data analysis (EDA) on this dataset, we can perform the following tasks:
#
# - Data Import: Import the dataset into a statistical software tool such as Python or R.
# - Data Cleaning: Check the dataset for any missing or incorrect data and clean the dataset accordingly. This may involve removing or imputing missing data or correcting any obvious errors.
# Data Description: Generate summary statistics such as mean, median, and standard deviation for each column of the dataset. This will help in understanding the distribution of data in each column.
# - Data Visualization: Create various visualizations such as histograms, box plots, scatter plots, and heatmaps to understand the relationships and trends between the different variables in the dataset. For example, we can create a scatter plot between the "Fresh" and "Milk" variables to see if there is any correlation between them.
# - Outlier Detection: Check for any outliers in the dataset and determine whether they are valid or erroneous data points.
# - Correlation Analysis: Calculate the correlation between different variables in the dataset to determine which variables are highly correlated and which ones are not. For example, we can calculate the correlation between "Grocery" and "Detergents_Paper" to see if there is any relationship between these two variables.
# - Data Transformation: If necessary, transform the data by standardizing or normalizing the variables to make them comparable across different scales.
# - Feature Selection: Identify the most important features or variables that contribute the most to the overall variance in the dataset. This can be done using various feature selection techniques such as principal component analysis (PCA) or random forest regression.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from sklearn.preprocessing import RobustScaler

# %%
# Load grocery data
df = pd.read_csv('Wholesale_data.csv')

# %%
df.shape
# Out:
# (440, 8)

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
# Checking for null values
df.isnull()
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0      False   False  False  False    False   False             False
# 1      False   False  False  False    False   False             False
# 2      False   False  False  False    False   False             False
# 3      False   False  False  False    False   False             False
# 4      False   False  False  False    False   False             False
# ..       ...     ...    ...    ...      ...     ...               ...
# 435    False   False  False  False    False   False             False
# 436    False   False  False  False    False   False             False
# 437    False   False  False  False    False   False             False
# 438    False   False  False  False    False   False             False
# 439    False   False  False  False    False   False             False
#
#      Delicassen
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# ...

# %%
# Count nulls per column
df.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
# Summary statistics
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
# Channel Distribution Chart
plt.figure(figsize=(8, 6))

# Get channel counts and calculate percentages
channel_counts = df['Channel'].value_counts().sort_index()
channel_labels = [f'Channel {i}' for i in channel_counts.index]
channel_percentages = (channel_counts / len(df) * 100).round(1)

# Create bar chart
bars = plt.bar(channel_labels, channel_counts.values, color=['#3B82F6', '#10B981'])

# Add labels and title
plt.title('Channel Distribution', fontweight='bold', fontsize=14)
plt.ylabel('Number of Customers')

# Add count and percentage labels on top of bars
for i, (bar, pct) in enumerate(zip(bars, channel_percentages)):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 5,
             f'{int(height)}\n({pct}%)', 
             ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# Region Distribution Chart
plt.figure(figsize=(8, 6))

# Get region counts and calculate percentages
region_counts = df['Region'].value_counts().sort_index()
region_labels = [f'Region {i}' for i in region_counts.index]
region_percentages = (region_counts / len(df) * 100).round(1)

# Create bar chart
bars = plt.bar(region_labels, region_counts.values, color=['#EF4444', '#F97316', '#EAB308'])

# Add labels and title
plt.title('Region Distribution', fontweight='bold', fontsize=14)
plt.ylabel('Number of Customers')

# Add count and percentage labels on top of bars
for i, (bar, pct) in enumerate(zip(bars, region_percentages)):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 5,
             f'{int(height)}\n({pct}%)', 
             ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# Average Spending by Channel
plt.figure(figsize=(12, 6))

# Define spending columns
spending_cols = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']

# Calculate average spending by channel
channel1_avg = df[df['Channel'] == 1][spending_cols].mean()
channel2_avg = df[df['Channel'] == 2][spending_cols].mean()

# Set up bar positions
x = np.arange(len(spending_cols))
width = 0.35

# Create bars
bars1 = plt.bar(x - width/2, channel1_avg, width, label='Channel 1', color='#3B82F6', alpha=0.8)
bars2 = plt.bar(x + width/2, channel2_avg, width, label='Channel 2', color='#10B981', alpha=0.8)

# Add labels and title
plt.title('Average Spending by Channel', fontweight='bold', fontsize=14)
plt.ylabel('Average Spending ($)')
plt.xlabel('Product Categories')
plt.xticks(x, spending_cols, rotation=45, ha='right')
plt.legend()

# Format y-axis to show values in thousands
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.tight_layout()
plt.show()

# %%
# Spending Heatmap by Channel & Category
plt.figure(figsize=(10, 4))

# Define spending columns
spending_cols = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']

# Calculate average spending by channel
heatmap_data = df.groupby('Channel')[spending_cols].mean()

# Create heatmap
sns.heatmap(heatmap_data, 
            annot=True,                    # Show values in cells
            fmt='.0f',                     # Format as integers
            cmap='Blues',                  # Blue color scheme
            cbar_kws={'label': 'Average Spending ($)'},
            linewidths=0.5)

# Customize labels
plt.title('Spending Heatmap by Channel & Category', fontweight='bold', fontsize=14)
plt.ylabel('Channel')
plt.xlabel('Product Categories')
plt.yticks([0.5, 1.5], ['Channel 1', 'Channel 2'], rotation=0)

plt.tight_layout()
plt.show()

# %%
# Fresh Spending Distribution
plt.figure(figsize=(10, 6))

# Create histogram of Fresh spending
plt.hist(df['Fresh'], bins=30, color='#22C55E', alpha=0.7, edgecolor='black')

# Add labels and title
plt.title('Distribution of Fresh Product Spending', fontweight='bold', fontsize=14)
plt.xlabel('Fresh Spending ($)')
plt.ylabel('Number of Customers')

# Format x-axis to show values in thousands
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Milk Spending Distribution
plt.figure(figsize=(10, 6))

# Create histogram of Milk spending
plt.hist(df['Milk'], bins=30, color='#3B82F6', alpha=0.7, edgecolor='black')

# Add labels and title
plt.title('Distribution of Milk Product Spending', fontweight='bold', fontsize=14)
plt.xlabel('Milk Spending ($)')
plt.ylabel('Number of Customers')

# Format x-axis to show values in thousands
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Grocery Spending Distribution
plt.figure(figsize=(10, 6))

# Create histogram of Grocery spending
plt.hist(df['Grocery'], bins=30, color='#EAB308', alpha=0.7, edgecolor='black')

# Add labels and title
plt.title('Distribution of Grocery Product Spending', fontweight='bold', fontsize=14)
plt.xlabel('Grocery Spending ($)')
plt.ylabel('Number of Customers')

# Format x-axis to show values in thousands
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Frozen Spending Distribution
plt.figure(figsize=(10, 6))

# Create histogram of Frozen spending
plt.hist(df['Frozen'], bins=30, color='#06B6D4', alpha=0.7, edgecolor='black')

# Add labels and title
plt.title('Distribution of Frozen Product Spending', fontweight='bold', fontsize=14)
plt.xlabel('Frozen Spending ($)')
plt.ylabel('Number of Customers')

# Format x-axis to show values in thousands
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Detergents_Paper Spending Distribution
plt.figure(figsize=(10, 6))

# Create histogram of Detergents_Paper spending
plt.hist(df['Detergents_Paper'], bins=30, color='#8B5CF6', alpha=0.7, edgecolor='black')

# Add labels and title
plt.title('Distribution of Detergents_Paper Product Spending', fontweight='bold', fontsize=14)
plt.xlabel('Detergents_Paper Spending ($)')
plt.ylabel('Number of Customers')

# Format x-axis to show values in thousands
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Delicassen Spending Distribution
plt.figure(figsize=(10, 6))

# Create histogram of Delicassen spending
plt.hist(df['Delicassen'], bins=30, color='#EF4444', alpha=0.7, edgecolor='black')

# Add labels and title
plt.title('Distribution of Delicassen Product Spending', fontweight='bold', fontsize=14)
plt.xlabel('Delicassen Spending ($)')
plt.ylabel('Number of Customers')

# Format x-axis to show values in thousands
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Average Spending by Channel
plt.figure(figsize=(12, 6))

# Define spending columns
spending_cols = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']

# Calculate average spending by channel
channel1_avg = df[df['Channel'] == 1][spending_cols].mean()
channel2_avg = df[df['Channel'] == 2][spending_cols].mean()

# Set up bar positions
x = np.arange(len(spending_cols))
width = 0.35

# Create bars
bars1 = plt.bar(x - width/2, channel1_avg, width, label='Channel 1', color='#3B82F6', alpha=0.8)
bars2 = plt.bar(x + width/2, channel2_avg, width, label='Channel 2', color='#10B981', alpha=0.8)

# Add labels and title
plt.title('Average Spending by Channel', fontweight='bold', fontsize=14)
plt.ylabel('Average Spending ($)')
plt.xlabel('Product Categories')
plt.xticks(x, spending_cols, rotation=45, ha='right')
plt.legend()

# Format y-axis to show values in thousands
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

plt.tight_layout()
plt.show()

# %%
# Look for outliers

features = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen'] 
plt.figure(figsize=(12, 6))

for i, feature in enumerate(features):
    plt.subplot(1, len(features), i+1)
    sns.boxplot(y=df[feature])
    plt.title(f'Boxplot of {feature}')

plt.tight_layout()
plt.show()

# %%
# Create correlation matrix
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                    Channel    Region     Fresh      Milk   Grocery    Frozen  \
# Channel           1.000000  0.062028 -0.169172  0.460720  0.608792 -0.202046
# Region            0.062028  1.000000  0.055287  0.032288  0.007696 -0.021044
# Fresh            -0.169172  0.055287  1.000000  0.100510 -0.011854  0.345881
# Milk              0.460720  0.032288  0.100510  1.000000  0.728335  0.123994
# Grocery           0.608792  0.007696 -0.011854  0.728335  1.000000 -0.040193
# Frozen           -0.202046 -0.021044  0.345881  0.123994 -0.040193  1.000000
# Detergents_Paper  0.636026 -0.001483 -0.101953  0.661816  0.924641 -0.131525
# Delicassen        0.056011  0.045212  0.244690  0.406368  0.205497  0.390947
#
#                   Detergents_Paper  Delicassen
# Channel                   0.636026    0.056011
# Region                   -0.001483    0.045212
# Fresh                    -0.101953    0.244690
# Milk                      0.661816    0.406368
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

# Simple Robust Scaling
scaler = RobustScaler()
spending_cols = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']

# Apply robust scaling to spending columns
df_scaled = df.copy()
df_scaled[spending_cols] = scaler.fit_transform(df[spending_cols])

# Check the result
print("Robust Scaled Data:")
print(df_scaled[spending_cols].head())
# Out:
# Robust Scaled Data:
#       Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# 0  0.301680  1.065712  0.329952 -0.466572          0.506787    0.263810
# 1 -0.104810  1.092934  0.565993  0.083926          0.675670    0.574008
# 2 -0.155802  0.915816  0.344418  0.312589          0.736512    4.871459
# 3  0.344850 -0.429714 -0.062862  1.734708         -0.084442    0.582507
# 4  1.022092  0.315171  0.287260  0.849573          0.262056    2.988314

# %%
# 1. PRINCIPAL COMPONENT ANALYSIS (PCA)
print("1. PRINCIPAL COMPONENT ANALYSIS")
print("=" * 50)

# Fit PCA
pca = PCA()
pca_features = pca.fit_transform(df_scaled[spending_cols])

# Explained variance ratio
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

print("Explained Variance by Component:")
for i, var in enumerate(explained_variance):
    print(f"PC{i+1}: {var:.3f} ({var*100:.1f}%)")

print(f"\nCumulative Explained Variance:")
for i, cum_var in enumerate(cumulative_variance):
    print(f"PC1-PC{i+1}: {cum_var:.3f} ({cum_var*100:.1f}%)")

# PCA Component Loadings (Feature Importance)
print(f"\nPCA Component Loadings (Feature Contributions):")
pca_components = pd.DataFrame(
    pca.components_.T,
    columns=[f'PC{i+1}' for i in range(len(spending_cols))],
    index=spending_cols
)
print(pca_components.round(3))

# 2. VARIANCE ANALYSIS
print("\n\n2. INDIVIDUAL FEATURE VARIANCE ANALYSIS")
print("=" * 50)

# Calculate variance for each feature
feature_variances = df_scaled[spending_cols].var().sort_values(ascending=False)
print("Feature Variance (Robust Scaled Data):")
for feature, variance in feature_variances.items():
    print(f"{feature}: {variance:.3f}")

# 3. FEATURE IMPORTANCE USING RANDOM FOREST
print("\n\n3. FEATURE IMPORTANCE (Random Forest)")
print("=" * 50)

# We'll use each spending category to predict the others (feature importance)
feature_importance_scores = {}

for target_col in spending_cols:
    # Use other features to predict this one
    X = df_scaled[spending_cols].drop(columns=[target_col])
    y = df_scaled[target_col]
    
    rf = RandomForestRegressor(n_estimators=100, random_state=42)
    rf.fit(X, y)
    
    # Store importance scores
    for i, feature in enumerate(X.columns):
        if feature not in feature_importance_scores:
            feature_importance_scores[feature] = []
        feature_importance_scores[feature].append(rf.feature_importances_[i])

# Average importance across all predictions
avg_importance = {feature: np.mean(scores) for feature, scores in feature_importance_scores.items()}
avg_importance = dict(sorted(avg_importance.items(), key=lambda x: x[1], reverse=True))

print("Average Feature Importance (Random Forest):")
for feature, importance in avg_importance.items():
    print(f"{feature}: {importance:.3f}")

# VISUALIZATIONS
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Feature Selection Analysis', fontsize=16)

# 1. PCA Explained Variance
axes[0, 0].bar(range(1, len(explained_variance)+1), explained_variance, color='#3B82F6', alpha=0.7)
axes[0, 0].plot(range(1, len(cumulative_variance)+1), cumulative_variance, 'ro-', color='#EF4444')
axes[0, 0].set_xlabel('Principal Component')
axes[0, 0].set_ylabel('Explained Variance Ratio')
axes[0, 0].set_title('PCA Explained Variance')
axes[0, 0].axhline(y=0.8, color='red', linestyle='--', alpha=0.7, label='80% threshold')
axes[0, 0].legend()

# 2. PCA Component Loadings Heatmap
sns.heatmap(pca_components.iloc[:, :3], annot=True, cmap='RdBu_r', center=0, ax=axes[0, 1])
axes[0, 1].set_title('PCA Component Loadings (First 3 PCs)')

# 3. Feature Variance
feature_var_df = pd.DataFrame({'Feature': feature_variances.index, 'Variance': feature_variances.values})
axes[1, 0].bar(feature_var_df['Feature'], feature_var_df['Variance'], color='#10B981', alpha=0.7)
axes[1, 0].set_xlabel('Features')
axes[1, 0].set_ylabel('Variance')
axes[1, 0].set_title('Individual Feature Variance')
axes[1, 0].tick_params(axis='x', rotation=45)

# 4. Random Forest Feature Importance
importance_df = pd.DataFrame({'Feature': list(avg_importance.keys()), 'Importance': list(avg_importance.values())})
axes[1, 1].bar(importance_df['Feature'], importance_df['Importance'], color='#F59E0B', alpha=0.7)
axes[1, 1].set_xlabel('Features')
axes[1, 1].set_ylabel('Importance Score')
axes[1, 1].set_title('Random Forest Feature Importance')
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# RECOMMENDATIONS
print("\n\n4. FEATURE SELECTION RECOMMENDATIONS")
print("=" * 50)

# Number of components for 80% and 95% variance
components_80 = np.argmax(cumulative_variance >= 0.8) + 1
components_95 = np.argmax(cumulative_variance >= 0.95) + 1

print(f"Components needed for 80% variance: {components_80}")
print(f"Components needed for 95% variance: {components_95}")

# Top features by different methods
print(f"\nTop 3 Features by Variance: {list(feature_variances.head(3).index)}")
print(f"Top 3 Features by Random Forest: {list(avg_importance.keys())[:3]}")

# Most important features in first PC
pc1_importance = np.abs(pca_components['PC1']).sort_values(ascending=False)
print(f"Top 3 Features in PC1: {list(pc1_importance.head(3).index)}")

print(f"\nRECOMMENDED FEATURE SELECTION:")
print(f"- For dimensionality reduction: Use first {components_80} principal components (80% variance)")
print(f"- For feature subset: Focus on {list(avg_importance.keys())[:3]} (highest RF importance)")
print(f"- For customer segmentation: PC1 captures main spending patterns")

# Create PCA-transformed dataset
df_pca = df.copy()
pca_feature_names = [f'PC{i+1}' for i in range(components_80)]
df_pca[pca_feature_names] = pca_features[:, :components_80]

print(f"\nPCA-transformed dataset created with {components_80} components")
print("Use df_pca for machine learning with reduced dimensions")
# Out:
# 1. PRINCIPAL COMPONENT ANALYSIS
# ...
# Explained Variance by Component:
# PC1: 0.444 (44.4%)
# PC2: 0.302 (30.2%)
# PC3: 0.150 (15.0%)
# PC4: 0.057 (5.7%)
# PC5: 0.039 (3.9%)
# PC6: 0.007 (0.7%)
#
# Cumulative Explained Variance:
# PC1-PC1: 0.444 (44.4%)
# PC1-PC2: 0.746 (74.6%)
# PC1-PC3: 0.897 (89.7%)
# PC1-PC4: 0.954 (95.4%)
# PC1-PC5: 0.993 (99.3%)
# PC1-PC6: 1.000 (100.0%)
#
# PCA Component Loadings (Feature Contributions):
#                     PC1    PC2    PC3    PC4    PC5    PC6
# Fresh             0.128 -0.125  0.107  0.955 -0.207 -0.049
# Milk              0.361  0.403  0.126  0.164  0.814 -0.049
# Grocery           0.219  0.468  0.176 -0.014 -0.306  0.780
# Frozen            0.442 -0.486  0.724 -0.210 -0.025 -0.009
# Detergents_Paper  0.180  0.584  0.231 -0.097 -0.423 -0.621
# Delicassen        0.760 -0.161 -0.604 -0.090 -0.148 -0.041
#
#
# 2. INDIVIDUAL FEATURE VARIANCE ANALYSIS
# ...
# Feature Variance (Robust Scaled Data):
# Delicassen: 3.989
# Frozen: 2.981
# Milk: 1.702
# ...

# %% [markdown]
# ## Part II - KMeans Clustering

# %% [markdown]
# The objective of the analysis is to group similar products together into clusters based on their attributes such as fresh, milk, grocery, frozen, detergents_paper, and delicatessen. To perform the k-means clustering analysis, you will need to pre-process the dataset, determine the optimal number of clusters, initialize the centroids, assign data points to clusters, update the centroids, and repeat until convergence.

# %%
# ELBOW METHOD
k_range = range(1, 10)
inertias = []

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_scaled[spending_cols])
    inertias.append(kmeans.inertia_)

# Plot elbow curve
plt.figure(figsize=(8, 6))
plt.plot(k_range, inertias, 'bo-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.grid(True, alpha=0.3)
plt.show()

# PERFORM CLUSTERING (choose k based on elbow)
optimal_k = 3  # Adjust this based on your elbow plot
print(f"Using k = {optimal_k} clusters")

kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['Cluster'] = kmeans.fit_predict(df_scaled[spending_cols])

# ANALYZE CLUSTERS
print("\nCluster Sizes:")
cluster_sizes = df['Cluster'].value_counts().sort_index()
for cluster, size in cluster_sizes.items():
    print(f"Cluster {cluster}: {size} customers ({size/len(df)*100:.1f}%)")

print("\nCluster Characteristics (Average Spending):")
cluster_means = df.groupby('Cluster')[spending_cols].mean()
print(cluster_means.round(0))

# CLUSTER BY CHANNEL ANALYSIS
print("\nCluster vs Channel Analysis:")
channel_cluster = pd.crosstab(df['Cluster'], df['Channel'], normalize='index') * 100
print(channel_cluster.round(1))
# Out:
# Using k = 3 clusters
#
# Cluster Sizes:
# Cluster 0: 405 customers (92.0%)
# Cluster 1: 1 customers (0.2%)
# Cluster 2: 34 customers (7.7%)
#
# Cluster Characteristics (Average Spending):
#            Fresh     Milk  Grocery   Frozen  Detergents_Paper  Delicassen
# Cluster
# 0        11913.0   4390.0   5952.0   3046.0            1843.0      1302.0
# 1        36847.0  43950.0  20170.0  36534.0             239.0     47943.0
# 2        12308.0  21426.0  31409.0   2396.0           15326.0      2811.0
#
# Cluster vs Channel Analysis:
# Channel      1     2
# Cluster
# 0         73.1  26.9
# 1        100.0   0.0
# 2          2.9  97.1

# %% [markdown]
# # Part III - Hierarchical Clustering

# %% [markdown]
# Hierarchical clustering is a popular unsupervised machine learning algorithm that is used to identify patterns and group similar data points together in a hierarchy. The algorithm works by iteratively merging or splitting clusters based on a similarity measure until a dendrogram is formed.
#
# To perform hierarchical clustering analysis, you will need to pre-process the dataset, determine the optimal number of clusters using techniques such as dendrogram.

# %% [markdown]
# The objective of the analysis is to group similar products together into clusters based on their attributes such as fresh, milk, grocery, frozen, detergents_paper, and delicatessen. To perform the k-means clustering analysis, you will need to pre-process the dataset, determine the optimal number of clusters, initialize the centroids, assign data points to clusters, update the centroids, and repeat until convergence.

# %% [markdown]
# The objective of the analysis is to group similar products together into clusters based on their attributes such as fresh, milk, grocery, frozen, detergents_paper, and delicatessen. To perform the k-means clustering analysis, you will need to pre-process the dataset, determine the optimal number of clusters, initialize the centroids, assign data points to clusters, update the centroids, and repeat until convergence.

# %% [markdown]
# The objective of the analysis is to group similar products together into clusters based on their attributes such as fresh, milk, grocery, frozen, detergents_paper, and delicatessen. To perform the k-means clustering analysis, you will need to pre-process the dataset, determine the optimal number of clusters, initialize the centroids, assign data points to clusters, update the centroids, and repeat until convergence.

# %% [markdown]
# # Part IV - PCA

# %% [markdown]
# In this section you are going to perform principal component analysis (PCA) to draw conclusions about the underlying structure of the wholesale customer data. Since using PCA on a dataset calculates the dimensions which best maximize variance, we will find which compound combinations of features best describe customers.

# %% [markdown]
# # Part V - Conclusion

# %% [markdown]
# From the model you developed and the exploratory data analysis (EDA) conducted, generate four bullet points as your findings.
